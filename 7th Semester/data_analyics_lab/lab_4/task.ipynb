# %% [markdown]
# # Lab 04: Data Analysis and Visualization

# %% [markdown]
# ## Task 1: Generate Random Data, Calculate Mean, and Plot Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
data = np.random.normal(loc=10, scale=1, size=100)

# %%
mean = np.mean(data)
mean
# Out:
# np.float64(9.884450140520334)

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data, kde=True, bins=10)
plt.axvline(mean, color='red', linestyle='--', label=f'Mean: {mean:.2f}')
plt.legend()
plt.title('Data Distribution with Mean')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Task 2: Calculate Median and Plot Distribution

# %%
median = np.median(data)
median
# Out:
# np.float64(9.953295061153305)

# %%
median = np.median(data)
plt.figure(figsize=(8, 6))
sns.histplot(data, kde=True, bins=10)
plt.axvline(median, color='green', linestyle='--', label=f'Median: {median:.2f}')
plt.legend()
plt.title('Data Distribution with Median')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Task 3: Calculate Mode and Plot Distribution

# %%
mode_result = stats.mode(data, keepdims=True)
mode = mode_result.mode if isinstance(mode_result.mode, np.ndarray) else mode_result.mode[0]
mode
mode_value = mode[0] if isinstance(mode, np.ndarray) else mode
mode_value
# Out:
# np.float64(7.605858443526187)

# %%
mode_result = stats.mode(data, keepdims=True)
mode = mode_result.mode if isinstance(mode_result.mode, np.ndarray) else mode_result.mode[0]
mode_value = mode[0] if isinstance(mode, np.ndarray) else mode
plt.figure(figsize=(8, 6))
sns.histplot(data, kde=True, bins=10)
plt.axvline(mode_value, color='blue', linestyle='--', label=f'Mode: {mode_value:.2f}')
plt.legend()
plt.title('Data Distribution with Mode')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Task 4: Calculate Min, Max, and Plot Boxplot

# %%
min_val = np.min(data)
max_val = np.max(data)
min_val, max_val
# Out:
# (np.float64(7.605858443526187), np.float64(11.941712524352312))

# %%
min_val = np.min(data)
max_val = np.max(data)
plt.figure(figsize=(8, 6))
sns.boxplot(data)
plt.text(0, min_val, f'Min: {min_val:.2f}', verticalalignment='center', color='red')
plt.text(0, max_val, f'Max: {max_val:.2f}', verticalalignment='center', color='blue')
plt.title('Boxplot with Min and Max Values')
plt.show()

# %% [markdown]
# ## Task 5: Calculate Variance and Plot Distribution

# %%
variance = np.var(data)
variance
# Out:
# np.float64(0.8487579341293062)

# %%
variance = np.var(data)
plt.figure(figsize=(8, 6))
sns.histplot(data, kde=True, bins=10)
plt.title(f'Data Distribution (Variance: {variance:.2f})')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Task 6: Calculate Standard Deviation and Plot Distribution

# %%
std_dev = np.std(data)
std_dev
# Out:
# np.float64(0.9212805946774881)

# %%
std_dev = np.std(data)
plt.figure(figsize=(8, 6))
sns.histplot(data, kde=True, bins=10)
plt.axvline(mean, color='red', linestyle='--', label='Mean')
plt.axvline(mean + std_dev, color='purple', linestyle='--', label='+1 Std Dev')
plt.axvline(mean - std_dev, color='purple', linestyle='--', label='-1 Std Dev')
plt.axvline(mean + 2 * std_dev, color='orange', linestyle='--', label='+2 Std Dev')
plt.axvline(mean - 2 * std_dev, color='orange', linestyle='--', label='-2 Std Dev')
plt.legend()
plt.title('Data Distribution with Standard Deviations')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Task 7: Calculate Quartiles and IQR, Plot Boxplot

# %%
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
Q1, Q3, IQR
# Out:
# (np.float64(9.379385158713593),
#  np.float64(10.441176987794115),
#  np.float64(1.0617918290805228))

# %%
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
plt.figure(figsize=(8, 6))
sns.boxplot(data)
plt.title(f'Boxplot with Quartiles and IQR\nQ1: {Q1:.2f}, Q3: {Q3:.2f}, IQR: {IQR:.2f}')
plt.show()

# %% [markdown]
# ## Task 8: Generate Skewed Dataset, Calculate Mean and Median, Plot Histogram

# %%
left_skewed_data = np.random.exponential(scale=2, size=100) - 2
right_skewed_data = np.random.exponential(scale=2, size=100)

# %%
left_mean = np.mean(left_skewed_data)
left_median = np.median(left_skewed_data)
left_mean, left_median
# Out:
# (np.float64(-0.03440479865526957), np.float64(-0.6257495666102129))

# %%
left_skewed_data = np.random.exponential(scale=2, size=100) - 2
right_skewed_data = np.random.exponential(scale=2, size=100)
left_mean = np.mean(left_skewed_data)
left_median = np.median(left_skewed_data)
plt.figure(figsize=(8, 6))
sns.histplot(left_skewed_data, kde=True)
plt.axvline(left_mean, color='red', linestyle='--', label='Mean')
plt.axvline(left_median, color='green', linestyle='--', label='Median')
plt.legend()
plt.title('Left Skewed Data with Mean and Median')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Task 9: Calculate Z-Scores and Plot Histogram

# %%
z_scores = stats.zscore(data)
z_scores
# Out:
# array([ 1.47557185, -0.45897887,  0.16881003,  0.64403198,  1.78909131,
#         0.07658948, -0.82048796, -1.2279773 , -1.90548818, -0.42658071,
#        -0.05792327,  0.56821028,  0.67307282, -1.01873892, -0.09351565,
#        -0.5458107 , -0.36643674,  0.25965985, -0.40163348,  2.79150046,
#         0.20829293, -1.17065629, -1.703106  ,  0.13771693,  0.97243119,
#        -2.81930375, -0.70680991,  0.23810323,  0.05520415, -0.08509977,
#         0.59954284, -0.49383809, -0.03637873,  0.38972927, -0.9765193 ,
#        -0.55545022,  0.57108632, -0.66532247,  0.12741852,  1.81121854,
#         0.55003105, -0.43625963, -0.6659642 , -0.23766266,  0.56449508,
#        -0.38054479,  0.8931223 ,  0.88802597,  0.36340522,  0.52039842,
#        -1.46946146,  0.44875947, -1.54861925, -1.95103615, -0.29934001,
#         1.66525332, -0.0981686 , -2.00048444, -1.0035637 , -0.09030337,
#         1.7483909 ,  0.50141515,  0.12785298,  0.07286536,  0.9766462 ,
# ...

# %%
z_scores = stats.zscore(data)
plt.figure(figsize=(8, 6))
sns.histplot(z_scores, kde=True)
plt.title('Histogram of Z-Scores')
plt.xlabel('Z-Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Task 10: Calculate Quartiles, IQR, Identify Outliers, and Plot

# %%
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = data[(data < lower_bound) | (data > upper_bound)]
outliers
# Out:
# array([12.45620534,  7.28708031,  7.72623358])

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data)
plt.scatter(np.full(outliers.shape, 0), outliers, color='red', label='Outliers')
plt.legend()
plt.title('Boxplot with Outliers')
plt.show()
